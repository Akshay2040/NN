# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Train_data.xlsx') #reads the data from the excel sheet and stores it in a pandas dataframe

# %%
df.head() #Displays a preview of the dataframe
# Out:
#    Pressure         Z  ρ (density)\n(g/cc)        µg  Bg\n(RB/Mscf)        Cg  \
# 0      14.7  0.999689             0.000674  0.013708     234.674291  0.068116
# 1     100.0  0.992184             0.004619  0.013749      34.238131  0.010089
# 2     200.0  0.983623             0.009318  0.013822      16.971368  0.005087
# 3     300.0  0.975343             0.014096  0.013912      11.218999  0.003418
# 4     400.0  0.967364             0.018950  0.014017       8.345416  0.002582
#
#            m(p)
# 0  1.576865e+04
# 1  7.325434e+05
# 2  2.936637e+06
# 3  6.618632e+06
# 4  1.177958e+07

# %%
X = df.drop('m(p)',axis=1)#Removes the m(p) column from the data frame and stores it in a new dataframe X.
#axis=1 signifies the column.
#axis=0 signifies the row. If we want to remove a row, we can add row heading instead with axis=0

# %%
X.head()#displays a preview of the data frame
# Out:
#    Pressure         Z  ρ (density)\n(g/cc)        µg  Bg\n(RB/Mscf)        Cg
# 0      14.7  0.999689             0.000674  0.013708     234.674291  0.068116
# 1     100.0  0.992184             0.004619  0.013749      34.238131  0.010089
# 2     200.0  0.983623             0.009318  0.013822      16.971368  0.005087
# 3     300.0  0.975343             0.014096  0.013912      11.218999  0.003418
# 4     400.0  0.967364             0.018950  0.014017       8.345416  0.002582

# %%
Y = df['m(p)'] #We can store just one column in the data frame too, by using this

# %%
Y#Just running the name of data frame gives the entire column
# Out:
# 0     1.576865e+04
# 1     7.325434e+05
# 2     2.936637e+06
# 3     6.618632e+06
# 4     1.177958e+07
#           ...
# 75    2.240088e+09
# 76    2.276099e+09
# 77    2.312053e+09
# 78    2.347951e+09
# 79    2.383793e+09
# Name: m(p), Length: 80, dtype: float64

# %%
Y.head() #Preview
# Out:
# 0    1.576865e+04
# 1    7.325434e+05
# 2    2.936637e+06
# 3    6.618632e+06
# 4    1.177958e+07
# Name: m(p), dtype: float64

# %%
X.values #converts the dataframe to a numpy array of shape (no. of entries, no. of headings)
# Out:
# array([[1.47000000e+01, 9.99688914e-01, 6.73877141e-04, 1.37080350e-02,
#         2.34674291e+02, 6.81164282e-02],
#        [1.00000000e+02, 9.92183659e-01, 4.61887485e-03, 1.37494985e-02,
#         3.42381306e+01, 1.00886797e-02],
#        [2.00000000e+02, 9.83623420e-01, 9.31814364e-03, 1.38219473e-02,
#         1.69713675e+01, 5.08702761e-03],
#        [3.00000000e+02, 9.75343003e-01, 1.40958785e-02, 1.39119788e-02,
#         1.12189985e+01, 3.41823082e-03],
#        [4.00000000e+02, 9.67364237e-01, 1.89495207e-02, 1.40166877e-02,
#         8.34541638e+00, 2.58247944e-03],
#        [5.00000000e+02, 9.59707103e-01, 2.38758895e-02, 1.41346350e-02,
#         6.62348685e+00, 2.07978615e-03],
#        [6.00000000e+02, 9.52389788e-01, 2.88711967e-02, 1.42649789e-02,
#         5.47748824e+00, 1.74349776e-03],
#        [7.00000000e+02, 9.45428734e-01, 3.39310663e-02, 1.44071767e-02,
#         4.66067405e+00, 1.50219998e-03],
# ...

# %%
Y.values #converts the dataframe to a numpy array
# Out:
# array([1.57686527e+04, 7.32543360e+05, 2.93663735e+06, 6.61863238e+06,
#        1.17795796e+07, 1.84155237e+07, 2.65178197e+07, 3.60733280e+07,
#        4.70645738e+07, 5.94699092e+07, 7.32636938e+07, 8.84165030e+07,
#        1.04895367e+08, 1.22664041e+08, 1.41683306e+08, 1.61911293e+08,
#        1.83303833e+08, 2.05814814e+08, 2.29396561e+08, 2.54000204e+08,
#        2.79576058e+08, 3.06073985e+08, 3.33443740e+08, 3.61635311e+08,
#        3.90599219e+08, 4.20286805e+08, 4.50650479e+08, 4.81643941e+08,
#        5.13222371e+08, 5.45342588e+08, 5.77963174e+08, 6.11044570e+08,
#        6.44549146e+08, 6.78441236e+08, 7.12687162e+08, 7.47255222e+08,
#        7.82115675e+08, 8.17240690e+08, 8.52604302e+08, 8.88182340e+08,
#        9.23952358e+08, 9.59893552e+08, 9.95986673e+08, 1.03221394e+09,
#        1.06855896e+09, 1.10500661e+09, 1.14154299e+09, 1.17815530e+09,
#        1.21483176e+09, 1.25156156e+09, 1.28833475e+09, 1.32514218e+09,
# ...
